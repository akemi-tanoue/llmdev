# %%
# 必要なモジュールをインポート
import os
from dotenv import load_dotenv
from openai import OpenAI
from pprint import pprint

# 環境変数の取得
load_dotenv("../.env")

# OpenAI APIクライアントを生成
client = OpenAI(api_key=os.environ['API_KEY'])

# モデル名
MODEL_NAME = "gpt-4o-mini"

# %%
# メッセージの設定
message = "言語モデルを使う上でのポイントは"

# APIへリクエスト
response = client.chat.completions.create(
    model=MODEL_NAME,
    messages=[
        {"role": "user", "content": message},
    ]
)

# レスポンスの表示
pprint(vars(response))
# Out:
# {'_request_id': 'req_a8dbce8f4873420bbce059da6f8bdd40',
#  'choices': [Choice(finish_reason='stop', index=0, logprobs=None, message=ChatCompletionMessage(content='言語モデルを使う上でのポイントはいくつかあります。以下に主なポイントを挙げます。\n\n1. **目的の明確化**:\n   - どのようなタスクに対して言語モデルを使用するのかを明確にすることが重要です。例えば、文章生成、要約、翻訳、質問応答など、目的に応じてアプローチが異なります。\n\n2. **入力データの質**:\n   - 言語モデルは入力データの質に大きく依存します。明確で具体的な質問やリクエストをすることで、より良い応答を得ることができます。\n\n3. **プロンプト設計**:\n   - プロンプト（入力文）の設計は重要です。コンテキストを提供し、期待する回答の形式を明示することで、モデルの応答の質を向上させることができます。\n\n4. **フィードバックループ**:\n   - モデルの応答に対してフィードバックを行うことで、次回のインタラクションを改善できます。必要に応じてプロンプトを修正し、何が有効だったのかを分析しましょう。\n\n5. **バイアスの理解**:\n   - 言語モデルは訓練データに基づいており、バイアスや偏見を持つ場合があります。そのため、生成された内容を批判的に評価し、必要に応じて修正や補足を加えることが大切です。\n\n6. **多様性の活用**:\n   - 同じ質問に対して異なるプロンプトを使うことで、多様な視点や発想を引き出せることがあります。これにより、より創造的な解決策や提案を得ることができます。\n\n7. **用途に応じたモデル選択**:\n   - 特定のタスクに特化したモデルや、汎用的なモデルのどちらが適当かを判断することも重要です。必要に応じてカスタマイズすることも検討しましょう。\n\n8. **結果の評価と改善**:\n   - 得られた結果は常に評価し、必要に応じてプロセスを改善することが求められます。目的に対するパフォーマンスを常にモニターしましょう。\n\n以上のポイントを押さえることで、言語モデルをより効果的に活用できるでしょう。', refusal=None, role='assistant', audio=None, function_call=None, tool_calls=None, annotations=[]))],
#  'created': 1758248931,
#  'id': 'chatcmpl-CHL9fE6e9hzVeMuRuJDWKWOwAPO6v',
#  'model': 'gpt-4o-mini-2024-07-18',
#  'object': 'chat.completion',
#  'service_tier': 'default',
#  'system_fingerprint': 'fp_560af6e559',
#  'usage': CompletionUsage(completion_tokens=570, prompt_tokens=18, total_tokens=588, completion_tokens_details=CompletionTokensDetails(accepted_prediction_tokens=0, audio_tokens=0, reasoning_tokens=0, rejected_prediction_tokens=0), prompt_tokens_details=PromptTokensDetails(audio_tokens=0, cached_tokens=0))}

# %%
# 言語モデルからの回答を表示
print(response.choices[0].message.content.strip())
# Out:
# 言語モデルを使う上でのポイントはいくつかあります。以下に主なポイントを挙げます。
#
# 1. **目的の明確化**:
#    - どのようなタスクに対して言語モデルを使用するのかを明確にすることが重要です。例えば、文章生成、要約、翻訳、質問応答など、目的に応じてアプローチが異なります。
#
# 2. **入力データの質**:
#    - 言語モデルは入力データの質に大きく依存します。明確で具体的な質問やリクエストをすることで、より良い応答を得ることができます。
#
# 3. **プロンプト設計**:
#    - プロンプト（入力文）の設計は重要です。コンテキストを提供し、期待する回答の形式を明示することで、モデルの応答の質を向上させることができます。
#
# 4. **フィードバックループ**:
#    - モデルの応答に対してフィードバックを行うことで、次回のインタラクションを改善できます。必要に応じてプロンプトを修正し、何が有効だったのかを分析しましょう。
#
# 5. **バイアスの理解**:
#    - 言語モデルは訓練データに基づいており、バイアスや偏見を持つ場合があります。そのため、生成された内容を批判的に評価し、必要に応じて修正や補足を加えることが大切です。
#
# 6. **多様性の活用**:
#    - 同じ質問に対して異なるプロンプトを使うことで、多様な視点や発想を引き出せることがあります。これにより、より創造的な解決策や提案を得ることができます。
#
# 7. **用途に応じたモデル選択**:
#    - 特定のタスクに特化したモデルや、汎用的なモデルのどちらが適当かを判断することも重要です。必要に応じてカスタマイズすることも検討しましょう。
#
# 8. **結果の評価と改善**:
#    - 得られた結果は常に評価し、必要に応じてプロセスを改善することが求められます。目的に対するパフォーマンスを常にモニターしましょう。
#
# 以上のポイントを押さえることで、言語モデルをより効果的に活用できるでしょう。

# %%
# 役割や前提の設定
role = "あなたはマーケティング分野に精通したビジネスコンサルタントです。企業の成長をサポートするために、効果的なマーケティング戦略を提供します。"

# メッセージの設定
message = "新製品の発売に向けた効果的なマーケティング戦略を教えてください。"

# APIへリクエスト
response = client.chat.completions.create(
    model=MODEL_NAME,
    messages=[
        {"role": "system", "content": role},
        {"role": "user", "content": message},
    ],
)

# 言語モデルからの回答を表示
print(response.choices[0].message.content.strip())
# Out:
# 新製品の発売に向けた効果的なマーケティング戦略には、以下のステップが含まれます。
#
# ### 1. 市場調査とターゲット設定
# - **市場分析**: 競合他社の製品、顧客ニーズ、トレンドを調査し、自社に優位性を持たせる要素を見つけます。
# - **ターゲット顧客の特定**: デモグラフィック（年齢、性別、収入など）、興味・関心、購買行動を基にターゲットを明確にします。
#
# ### 2. 製品のポジショニング
# - **ユニークな価値提案（UVP）の明確化**: 他社製品と差別化できるポイントを見つけ、顧客にどのように価値を提供するかを明確にします。
# - **メッセージング**: 製品の特徴や利点を明確で魅力的なメッセージとして構築します。
#
# ### 3. マーケティングミックスの構築（4P戦略）
# - **製品（Product）**: 製品のデザイン、機能、品質を決定します。
# - **価格（Price）**: 競争力と見込み客の価格感度を考慮し、価格設定を行います。
# - **流通（Place）**: どのチャネルを通じて製品を販売するかを決定します。オンラインショップ、実店舗、卸売など。
# - **プロモーション（Promotion）**: 広報活動や広告、SNS、インフルエンサーの活用など、知名度を上げるための方法を計画します。
#
# ### 4. プレビューストラテジー
# - **ティーザーキャンペーン**: 製品発売前に興味を引くためのティーザー広告やSneak Peekを実施し、期待感を高めます。
# - **プレスリリース**: メディアに向けたプレスリリースを配信し、広く認知を得る。
#
# ### 5. ローンチイベント
# - **製品発表会**: メディアやインフルエンサーを招待したプレスイベントを行い、実際に製品を体験してもらいます。
# - **SNSライブ配信**: 発売日に合わせてSNSでのライブ配信を行い、リアルタイムでのエンゲージメントを促進します。
#
# ### 6. フィードバックと調整
# - **顧客からのフィードバックの収集**: 社会的な証明と口コミを促進するための評価や感想を集めます。
# - **データ分析**: 売上データや利用状況を分析し、必要に応じてマーケティング戦略を調整します。
#
# ### 7. 継続的なマーケティング活動
# - **コンテンツマーケティング**: 製品関連のブログ記事やビデオコンテンツを作成し、長期的な顧客関係を構築します。
# - **リマーケティング**: 製品に関心を示したが購入に至らなかったユーザーに対してリマインダー広告を配信します。
#
# これらの戦略を組み合わせることで、新製品の発売を成功に導くことができます。企業のブランドや製品特性に合わせて調整し、柔軟に実行していくことが重要です。
